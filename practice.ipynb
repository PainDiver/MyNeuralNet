# %%
def funcinfunc(f):
    def funcinside(x,num):
        return x * f(num)
    return funcinside

def returnX(x):
    return x


g = funcinfunc(returnX)

print(g(5,8))


class minsik():
    age =0
    def __init__(self, age=0):
        self.age =age
    def GetOlder(self):
        self.age +=1
       
    def instance(self):
        return self
    def GetAge(self):
        return self.age
    
min = minsik(5)

print(min.GetAge())
assert min.GetAge() == 5, "wrong"

increasing_pairs = [(x,y) for x in range(10) for y in range(x+1,10)]

increasing_pairs

ssi= [1,2,3]

bal= ["a","s","d"]

pair = [li for li in zip(ssi,bal)]

ssi,bal = zip(*pair)

def test(*args,**kwargs):
    print("args:",args)
    print("kwargs:",kwargs)

a = ["dsa",1,34]
b = {"s":3}
test(*a,**b)
    
from typing import Union
# Out:
# 40
# 5
# args: ('dsa', 1, 34)
# kwargs: {'s': 3}
# ['asd', 5, 5.2]
