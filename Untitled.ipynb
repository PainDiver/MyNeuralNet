# %%
ssibal = {"f":1,"u":2,"c":3,"k":4}

a = ssibal.get("b","없음")

print(ssibal.items())
# Out:
# dict_items([('f', 1), ('u', 2), ('c', 3), ('k', 4)])

# %%
from collections import defaultdict,Counter


document = ["Fuck This Subject","go to hell", "shit"]

word_counts = defaultdict(int)

for word in document:
    word_counts[word] += 1

word_counts = Counter(document)


for word,count in word_counts.most_common(2):
    print(word,count)
    
s = set()
s.add("asd")
s.add("dss")
s.add("asd")

print(s)

x=2

a = 51 if x==3 else 30
    
print(f"{a} is a")

dic = {"김효훈":(4.5),"나호빈":(3.8),"강호석":(4.2)}

dict(sorted(dic.items(), key= lambda v: v[1],reverse=True))
# Out:
# Fuck This Subject 1
# go to hell 1
# {'dss', 'asd'}
# 30 is a
# {'김효훈': 4.5, '강호석': 4.2, '나호빈': 3.8}
